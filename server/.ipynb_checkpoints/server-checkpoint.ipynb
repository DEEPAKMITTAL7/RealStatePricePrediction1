# %%
from flask import Flask, request, jsonify
from waitress import serve
import util
#%run util.ipynb

app = Flask(__name__)

@app.route('/locations')
def locations():
    
    response = jsonify({
        'locations' : util.locations()
    })
    response.headers.add('Access-Control-Allow-Origin','*')
    
    return response

@app.route('/')
def hello():
    return hello


@app.route('/predict_home_price',methods=['POST'])
def predict_home_price():
    total_sqft = float(request.files['total_sqft'])
    location = request.files['location']
    size = int(request.files['size'])
    bath = int(request.files['bath'])
    area_type = request.files['area_type']
    balcony = int(request.files['balcony'])
    
    response = jsonify({
        'estimated_price': util.get_estimated_price(area_type,location,size,total_sqft,bath,balcony)
    })
    
    response.headers.add('Access-Control-Allow-Origin','*')
    
    return response

if __name__ == '__main__':
    print('python flask started')
    #app.run()
    serve()
# Out:
# python flask started
# ERROR:__main__:Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1842, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2162, in make_response
#     raise TypeError(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2158, in make_response
#     rv = self.response_class.force_type(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\wrappers\response.py", line 268, in force_type
#     response = Response(*run_wsgi_app(response, environ))
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\test.py", line 1242, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: hello() takes 0 positional arguments but 2 were given
# The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a function.
# ERROR:__main__:Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1842, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2162, in make_response
#     raise TypeError(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2158, in make_response
#     rv = self.response_class.force_type(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\wrappers\response.py", line 268, in force_type
#     response = Response(*run_wsgi_app(response, environ))
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\test.py", line 1242, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: hello() takes 0 positional arguments but 2 were given
# The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a function.
# ERROR:__main__:Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1842, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2162, in make_response
#     raise TypeError(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2158, in make_response
#     rv = self.response_class.force_type(
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\wrappers\response.py", line 268, in force_type
#     response = Response(*run_wsgi_app(response, environ))
#   File "C:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\test.py", line 1242, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: hello() takes 0 positional arguments but 2 were given
# The view function did not return a valid response. The return type must be a string, dict, list, tuple with headers or status, Response instance, or WSGI callable, but it was a function.
